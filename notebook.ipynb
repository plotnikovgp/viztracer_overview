# %%
# You need to load the extension first
# %load_ext viztracer

# %%
# %%viztracer
# # Code you want to profile inside the cell

# %% [markdown]
# ### More fun features

# %% [markdown]
# #### Flamegraph

# %%
# !vizviewer --flamegraph result.json

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Remote attach
# ```bash
# viztracer --attach <pid> -o result.json -t <seconds>
# ```

# %% [markdown]
# #### Virtual Debug
# just to mention
